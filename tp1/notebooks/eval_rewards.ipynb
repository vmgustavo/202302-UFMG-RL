# %%
import polars as pl
import matplotlib.pyplot as plt

# %%
rewards = pl.read_csv('../outputs/n_episodes_50000/20231004T210835/episodes_50000__rewards.csv', has_header=False)

# %%
window_size = int(rewards.shape[0] * 0.1)
window_size
# Out:
# 5000

# %%
plt.figure(figsize=(12, 3))
ax = plt.gca()

(
    rewards
    .to_series()
    .rolling_mean(window_size=window_size)
    .to_pandas()
    .plot(ax=ax)
)
# Out:
# <Axes: >

# %% [markdown]
# ---
